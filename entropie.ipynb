# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0,10,0.1)
y = [-np.log(e) for e in x]
plt.plot(x,y)
plt.grid(True)
plt.show()
# Out:
# /home/thoreau/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
